# %%
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df_exc = pd.read_hdf('data/exchanges.h5', key='data')
df_exc['created_at']= pd.to_datetime(df_exc['created_at'])
df_exc.head()
# Out:
#    conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 0         46206392     68934690 2022-07-16     3621147        3621147
# 1         47838047     70678856 2022-10-25     2595152        2595152
# 2         46453678     69197483 2022-08-01      689341         689341
# 3         41439268     63540384 2021-09-06     3528079        3528079
# 4         42477400     64699420 2021-12-19     3749583        3749583
#
#    host_user_id finalized_at canceled_at    start_on      end_on  ...  \
# 0       4033514          NaT         NaT  2022-08-01  2022-08-02  ...
# 1       3980440          NaT         NaT        None        None  ...
# 2       4027070          NaT         NaT  2022-08-11  2022-08-15  ...
# 3        337677          NaT         NaT  2021-12-26  2022-01-02  ...
# 4        336788          NaT         NaT  2021-12-26  2021-12-30  ...
#
#    user_cancellation_id   exchange_type  home_type residence_type capacity  \
# 0                   NaN  NON_RECIPROCAL  apartment        primary      4.0
# 1                   NaN  NON_RECIPROCAL       Home        primary      6.0
# 2                   NaN  NON_RECIPROCAL       Home        primary     10.0
# 3                   NaN  NON_RECIPROCAL  apartment      secondary      9.0
# 4                   NaN  NON_RECIPROCAL  apartment      secondary      6.0
#
#   country                      region       department  city  k
# 0     FRA  Provence-Alpes-Côte D'azur  Alpes-Maritimes  Nice  1
# 1     FRA  Provence-Alpes-Côte D'azur  Alpes-Maritimes  Nice  1
# 2     FRA  Provence-Alpes-Côte D'azur  Alpes-Maritimes  Nice  1
# 3     FRA  Provence-Alpes-Côte D'azur  Alpes-Maritimes  Nice  1
# 4     FRA  Provence-Alpes-Côte D'azur  Alpes-Maritimes  Nice  1
#
# [5 rows x 22 columns]

# %%
min(df_exc.created_at)
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df_exc.columns
# Out:
# Index(['conversation_id', 'exchange_id', 'created_at', 'creator_id',
#        'guest_user_id', 'host_user_id', 'finalized_at', 'canceled_at',
#        'start_on', 'end_on', 'guest_countguest_count', 'night_count',
#        'user_cancellation_id', 'exchange_type', 'home_type', 'residence_type',
#        'capacity', 'country', 'region', 'department', 'city', 'k'],
#       dtype='object')

# %%
df_exc[(df_exc.host_user_id==1110107)].sort_values('created_at')
# Out:
#          conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 5011663         31859676     53181443 2019-03-02      159348         159348
# 8032599         32801092     54156545 2019-04-27     2734712        2734712
# 166676          33049895     54413948 2019-05-13     3004982        3004982
# 1417528         33250802     54621228 2019-05-27      332359         332359
# 6337936         33552506     54969183 2019-06-19     1110107        2293350
# ...                  ...          ...        ...         ...            ...
# 5717810         47942902     70791912 2022-11-01     3989335        3989335
# 4350557         47963601     70814220 2022-11-02     4007826        4007826
# 12349           48003496     70856975 2022-11-05     3183164        3183164
# 1816307         48163114     71028941 2022-11-14     3103666        3103666
# 2438043         48169967     71036284 2022-11-15     4028867        4028867
#
#          host_user_id              finalized_at canceled_at    start_on  \
# 5011663       1110107                       NaT         NaT        None
# 8032599       1110107 2019-04-27 20:50:18+00:00         NaT  2019-08-04
# 166676        1110107                       NaT         NaT  2019-05-24
# 1417528       1110107                       NaT         NaT        None
# 6337936       1110107                       NaT         NaT        None
# ...               ...                       ...         ...         ...
# 5717810       1110107                       NaT         NaT  2023-03-25
# 4350557       1110107                       NaT         NaT  2023-01-04
# 12349         1110107                       NaT         NaT  2023-02-18
# 1816307       1110107                       NaT         NaT  2022-12-12
# 2438043       1110107                       NaT         NaT  2023-03-11
#
#              end_on  ...  user_cancellation_id   exchange_type  home_type  \
# 5011663        None  ...                   NaN  NON_RECIPROCAL  apartment
# 8032599  2019-08-07  ...                   NaN  NON_RECIPROCAL  apartment
# 166676   2019-05-25  ...                   NaN  NON_RECIPROCAL  apartment
# 1417528        None  ...                   NaN  NON_RECIPROCAL  apartment
# 6337936        None  ...                   NaN      RECIPROCAL  apartment
# ...             ...  ...                   ...             ...        ...
# 5717810  2023-03-31  ...                   NaN  NON_RECIPROCAL  apartment
# 4350557  2023-01-20  ...                   NaN  NON_RECIPROCAL  apartment
# 12349    2023-02-22  ...                   NaN  NON_RECIPROCAL  apartment
# 1816307  2023-01-02  ...                   NaN  NON_RECIPROCAL  apartment
# 2438043  2023-03-18  ...                   NaN  NON_RECIPROCAL  apartment
#
#         residence_type capacity country   region       department        city  \
# 5011663        primary      4.0     USA  Florida  Pinellas County  Clearwater
# 8032599        primary      4.0     USA  Florida  Pinellas County  Clearwater
# 166676         primary      4.0     USA  Florida  Pinellas County  Clearwater
# 1417528        primary      4.0     USA  Florida  Pinellas County  Clearwater
# 6337936        primary      4.0     USA  Florida  Pinellas County  Clearwater
# ...                ...      ...     ...      ...              ...         ...
# 5717810        primary      4.0     USA  Florida  Pinellas County  Clearwater
# 4350557        primary      4.0     USA  Florida  Pinellas County  Clearwater
# 12349          primary      4.0     USA  Florida  Pinellas County  Clearwater
# 1816307        primary      4.0     USA  Florida  Pinellas County  Clearwater
# 2438043        primary      4.0     USA  Florida  Pinellas County  Clearwater
#
#          k
# 5011663  1
# 8032599  1
# 166676   1
# 1417528  1
# 6337936  1
# ...     ..
# 5717810  1
# 4350557  1
# 12349    1
# 1816307  1
# 2438043  1
#
# [186 rows x 22 columns]
