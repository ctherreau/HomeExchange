# %%
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df_exc = pd.read_hdf('data/exchanges.h5', key='data')
df_exc['created_at']= pd.to_datetime(df_exc['created_at'])
df_exc.head()
# Out:
#    conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 0         46206392     68934690 2022-07-16     3621147        3621147
# 1         47838047     70678856 2022-10-25     2595152        2595152
# 2         46453678     69197483 2022-08-01      689341         689341
# 3         41439268     63540384 2021-09-06     3528079        3528079
# 4         42477400     64699420 2021-12-19     3749583        3749583
#
#    host_user_id finalized_at canceled_at    start_on      end_on  ...  \
# 0       4033514          NaT         NaT  2022-08-01  2022-08-02  ...
# 1       3980440          NaT         NaT        None        None  ...
# 2       4027070          NaT         NaT  2022-08-11  2022-08-15  ...
# 3        337677          NaT         NaT  2021-12-26  2022-01-02  ...
# 4        336788          NaT         NaT  2021-12-26  2021-12-30  ...
#
#    user_cancellation_id   exchange_type  home_type residence_type capacity  \
# ...

# %%
min(df_exc.created_at)
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df_exc.columns
# Out:
# Index(['conversation_id', 'exchange_id', 'created_at', 'creator_id',
#        'guest_user_id', 'host_user_id', 'finalized_at', 'canceled_at',
#        'start_on', 'end_on', 'guest_countguest_count', 'night_count',
#        'user_cancellation_id', 'exchange_type', 'home_type', 'residence_type',
#        'capacity', 'country', 'region', 'department', 'city', 'k'],
#       dtype='object')

# %%
df_exc[(df_exc.guest_user_id==3204313)].sort_values('created_at')
# Out:
#          conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 1866763         35452260     56890408 2019-11-19     3204313        3204313
# 5789361         35452179     56890324 2019-11-19     3204313        3204313
# 90533           41115971     63185876 2021-07-31     3204313        3204313
#
#          host_user_id finalized_at canceled_at    start_on      end_on  ...  \
# 1866763       1231794          NaT         NaT  2020-02-15  2020-02-17  ...
# 5789361       1283051          NaT         NaT  2020-02-15  2020-02-17  ...
# 90533           96389          NaT         NaT        None        None  ...
#
#          user_cancellation_id   exchange_type  home_type residence_type  \
# 1866763                   NaN  NON_RECIPROCAL  apartment        primary
# 5789361                   NaN  NON_RECIPROCAL  apartment        primary
# 90533                     NaN  NON_RECIPROCAL  apartment        primary
#
#         capacity country    region  department        city  k
# ...

# %%
users_616199
# Out:
#           conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 10615833         38112846     59809133 2020-07-13     2441089        2441089
# 3649910          38134970     59833050 2020-07-15      190071         190071
# 4261258          38133474     59831403 2020-07-15        1309           1309
# 10232501         38180378     59882294 2020-07-20        9904           9904
# 10857681         38193215     59896316 2020-07-21        9904           9904
# ...                   ...          ...        ...         ...            ...
# 4704330          44732963     67280747 2022-04-28      712447         712447
# 1180816          46480178     69225685 2022-08-02      258077         258077
# 11269836         46681977     69439263 2022-08-15     3781819        3781819
# 11054839         47225594     70022551 2022-09-19     3984226        3984226
# 8620858          47458873     70273296 2022-10-03     2803687        2803687
#
# ...

# %%
df_exc[(df_exc.guest_user_id==278511) & (~df_exc.finalized_at.isna())].sort_values('created_at')
# Out:
#          conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 6558251         32951925     54312671 2019-05-06      278511         278511
# 1588562         34085638     55541401 2019-07-29     3111463         278511
# 7206816         34191060     55618406 2019-08-06     3038670         278511
# 1541309         34218158     57178759 2019-08-08      367691         278511
# 3853850         38488360     60224158 2020-09-01     2663117         278511
# 3497219         41320602     63409293 2021-08-23     1138390         278511
# 9048195         41619877     63741716 2021-09-25      278511         278511
# 6991142         42478915     64782831 2021-12-19     3173460         278511
# 9278823         42589007     65012462 2022-01-03     2387997         278511
# 687998          42720228     65265149 2022-01-13      451684         278511
# 1741636         42803751     65874026 2022-01-19     2792812         278511
# ...

# %%
df_exc[(df_exc.host_user_id==102777) & (df_exc.exchange_type=='RECIPROCAL')].sort_values('created_at')
# Out:
#           conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 4312978          35817213     57406781 2019-12-21      102777        1166480
# 302983           36612680     58112261 2020-02-03      102777          68835
# 10768119         36678505     58187887 2020-02-06      102777        1387599
# 159540           36811355     58435335 2020-02-13      102777        3138793
# 10678529         36811396     58372330 2020-02-13      102777        1482275
# 5681342          36870284     58411000 2020-02-16      102777          67177
# 1601451          37637493     59278106 2020-06-09      253153         253153
# 4024359          37777654     59436955 2020-06-18     1566825        1566825
# 9428458          37864513     59534385 2020-06-24      102777        1151263
# 11222166         37864748     59534652 2020-06-24      102777        2603075
# 10891925         37864696     59534588 2020-06-24      102777        2739178
# ...

# %%
df_exc[(df_exc.guest_user_id==102777) & (df_exc.exchange_type=='RECIPROCAL')].sort_values('created_at')
# Out:
#           conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 10442015         35817213     57267307 2019-12-21      102777         102777
# 415581           36612680     58112260 2020-02-03      102777         102777
# 5832476          36678505     58187886 2020-02-06      102777         102777
# 2966126          36811355     58339091 2020-02-13      102777         102777
# 8427376          36811396     58339134 2020-02-13      102777         102777
# 6523887          36870284     58406068 2020-02-16      102777         102777
# 11164692         37637493     59278107 2020-06-09      253153         102777
# 2362147          37777654     59436956 2020-06-18     1566825         102777
# 8274784          37864762     59534666 2020-06-24      102777         102777
# 10873741         37864748     59534651 2020-06-24      102777         102777
# 9231984          37864513     59534384 2020-06-24      102777         102777
# ...

# %%
22905/414678*100
# Out:
# 5.523562860822132

# %%
df_exc[(df_exc.guest_user_id==313395)&(df_exc.creator_id!=313395)]
# Out:
#          conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 4617682         32054010     53570601 2019-03-12      535815         313395
# 4962729         40156475     62654542 2021-05-15      690976         313395
# 9602636         41996184     64161247 2021-10-29     2861105         313395
#
#          host_user_id finalized_at canceled_at    start_on      end_on  ...  \
# 4617682        535815          NaT         NaT  2019-08-20  2019-08-23  ...
# 4962729        690976          NaT         NaT  2021-08-15  2021-08-22  ...
# 9602636       2861105          NaT         NaT  2022-04-11  2022-04-30  ...
#
#          user_cancellation_id  exchange_type  home_type residence_type  \
# 4617682                   NaN     RECIPROCAL       Home        primary
# 4962729                   NaN     RECIPROCAL  apartment      secondary
# 9602636                   NaN     RECIPROCAL       Home        primary
#
# ...

# %%
df_exc[(df_exc.host_user_id==313395) & (df_exc.exchange_type=='NON_RECIPROCAL')]
# Out:
#           conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 1661488          41630593     63753852 2021-09-26     2687740        2687740
# 2392249          37333061     58935193 2020-05-02     2633680        2633680
# 3146581          36341673     57810232 2020-01-21     2739843        2739843
# 4763454          41750203     63887293 2021-10-07      118240         118240
# 5504008          35531230     56972183 2019-11-25     2201931        2201931
# 5922736          40862815     62905385 2021-07-06      362605         362605
# 6054388          45520281     68171794 2022-06-07       65232          65232
# 6420179          44950957     67529142 2022-05-09     3167404        3167404
# 6517696          41540739     63653210 2021-09-17     2815462        2815462
# 6574153          42379921     64590937 2021-12-06     3849769        3849769
# 7004111          45829286     68517932 2022-06-24      383864         383864
# ...

# %%
df_exc[df_exc.host_user_id==758307]
# Out:
#           conversation_id  exchange_id created_at  creator_id  guest_user_id  \
# 1671655          47722587     70554753 2022-10-19      760818         760818
# 1685660          47715312     70547056 2022-10-18     2750798        2750798
# 1760594          47717543     70549455 2022-10-18     3032203        3032203
# 1823756          47723060     70555254 2022-10-19       17885          17885
# 1852615          47736413     70569764 2022-10-19      498703         498703
# ...                   ...          ...        ...         ...            ...
# 11521233         47723602     70555850 2022-10-19     3696146        3696146
# 11569933         47715695     70547475 2022-10-18     1392269        1392269
# 11635355         47736893     70570270 2022-10-19     2276816        2276816
# 11752760         47753254     70587754 2022-10-20     3237905        3237905
# 11752763         47728728     70561354 2022-10-19     3288133        3288133
#
# ...
